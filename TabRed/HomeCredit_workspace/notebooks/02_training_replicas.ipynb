# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install optuna

# %% [markdown]
# # 02 — Training Replicas
#
# For each window pair (A, B) this notebook:
#
# 1. Tunes hyperparameters **per window** using Optuna with TimeSeriesSplit, optimising PR-AUC.
# 2. Trains **R replicas** per window using stratified bootstrap sampling + different random seeds.
# 3. Evaluates on the common evaluation slice E_{A,B} (replica-averaged predictions, PR-AUC and ROC-AUC).
# 4. Identifies the **flagged set** F_{A,B} as the top K_FRAC fraction of eval instances ranked by max(p_hat_A, p_hat_B).
#
# **Model types supported:** `'xgboost'` | `'logreg'`  ← set via `MODEL_TYPE` in the config cell.
# MLP-PLR is trained in `02b_training_replicas_mlp_plr.ipynb`.
#
# ## Per-(window, side) preprocessing
#
# A single `OrdinalEncoder(min_frequency=1/100, handle_unknown='use_encoded_value', unknown_value=-1)` is fit **once per (window, side)** on that window's full training rows and saved to `replicas_<side>/encoder.joblib`. Every bootstrap replica of that side reuses the same encoder, so categorical integer codes are stable across replicas — a prerequisite for SHAP / LIME / coefficient comparisons in 03 / 03b / 04. Categories appearing in <1% of the window collapse to a single bucket; categories absent from the window that show up at inference time get `-1`. The same shared encoder is also used inside Optuna's TimeSeriesSplit folds so tuning's preprocessing matches replica training.
#
# Because the ordinal codes carry an arbitrary monotonic ordering that none of these models should treat as semantically meaningful, every model receives the **one-hot expansion** of those codes. A `OneHotEncoder(handle_unknown='ignore')` is fit per (window, side) on the OrdinalEncoder's integer output and saved to `replicas_<side>/one_hot.joblib`; XGBoost and LR (this notebook) and MLP-PLR (in `02b`) all consume `[numeric | binary | one-hot dummies]`. SHAP / LIME later aggregate dummy attributions back to the per-cat-variable axis (sum for SHAP; LIME's `predict_fn` applies the encoder model-side so LIME never sees dummies) — see 03 / 03b.
#
# The LR pipeline uses `ColumnTransformer({StandardScaler on numeric, passthrough on binary + one-hot})` so the scaler is applied only where it makes sense; binaries and one-hot dummies stay on their natural 0/1 scale (already a common reference frame across windows).
#
# ## Class weighting (operational retraining pipeline)
#
# Both XGBoost and logistic regression are fitted with **balanced sample weights** equivalent to sklearn's `class_weight='balanced'`:
#
# ```
# w_pos = n / (2 * n_pos)        w_neg = n / (2 * n_neg)        n = n_pos + n_neg
# ```
#
# This applies to every fit performed in the notebook — Optuna folds, replica fits, and the deterministic full-window LR fits — and is part of the operational retraining pipeline rather than a per-dataset toggle. Concretely:
#
# - Weights are computed once per side from the **actual optimization-training portion**: the bootstrap source (training core before the chronological early-stopping tail) for XGBoost, and the full window for LR (which has no ES tail). All R replicas of a side share the same `{w_pos, w_neg}` mapping; the bootstrap remains class-stratified and the per-row sample weights for each replica are derived from the side-level mapping rather than recomputed per replica.
# - Optuna folds compute fold-level balanced weights from `Y[fold_train]` only, never from the fold-validation portion.
# - The deterministic full-window LR fits (transparent A-vs-B reference) get their own balanced weights from the full window.
# - A and B may end up with **different** weights because their class balance can differ across temporal windows; this is intentional and is part of what we measure as end-to-end explanation drift.
# - Weights are **never clipped**. With HomeCredit's ~3% positive rate, w_pos ≈ 16 and w_neg ≈ 0.5 in practice — the asymmetry is by design and is recorded as-is in `class_weights.json`.
# - Validation/test PR-AUC and ROC-AUC remain **unweighted** — XGBoost's `eval_set` AUCPR (used for early stopping) is unweighted by default, and `average_precision_score` / `roc_auc_score` are called without `sample_weight`.
#
# The realised `{n_pos, n_neg, w_pos, w_neg}` for each side / window / pair is written to `class_weights.json` inside each pair directory; the scheme itself participates in the `run_params.json` staleness fingerprint, so any change to the weighting policy invalidates cached predictions and downstream SHAP / LIME / drift artefacts.
#
# ## LR coefficient layout for cross-window comparison
#
# Each LR replica produces `n_num + n_bin + n_oh` raw coefficients (where `n_oh = sum_j K_j`, the total dummy count after one-hot expansion). For the cross-window drift / cosine / RBO analysis in 04 we need one number per categorical *variable*, not per dummy. After projecting the numerics to the pair-level reference scaler basis (binaries stay raw 0/1) we **L2-aggregate the dummy coefficients per cat variable**: `β_cat[j] = ‖β_dummies_for_cat_j‖₂`. The result lives in a `(n_num + n_bin + n_cat,)` reference-basis vector per replica, on the same axis as `feature_names['all'] + feature_names['cat']`. Per-dummy coefficients remain recoverable from the saved replica `Pipeline` (which contains the trained ColumnTransformer); the shared encoder + one-hot artifacts let you map dummy positions back to (cat var, category) pairs.
#
# ## ES validation correctness
#
# For XGBoost, the early-stopping validation slice is the chronological **tail** of the training window, held out **before** bootstrapping. This guarantees ES monitors out-of-time data rather than a random slice of a shuffled bootstrap. Class-weighting metadata reflects this distinction (`replica_data_scope = training_core_before_early_stopping_tail` for XGBoost, `full_window_no_es` for LR).
#
# ## HomeCredit-specific notes
#
# - **Heavy class imbalance.** Default rate is ~3.2% (vs Homesite's ~19% conversion rate). Unweighted PR-AUC values will be much lower in absolute terms — typically in the 0.05–0.15 range rather than Homesite's 0.4–0.5. This is expected for a heavily imbalanced binary classification task and does not indicate a poor fit on its own; ROC-AUC is a more comparable cross-implementation metric. The class-weighting policy above is what compensates for the imbalance during fitting; PR-AUC reporting itself remains on the natural distribution so values stay comparable to other Home Credit baselines.
# - **Larger feature space.** After per-window one-hot expansion, the combined matrix has roughly 1100–1500 columns (HomeCredit's `n_num + n_bin ≈ 720` plus 400–800 dummies from ~84 cat variables, depending on category counts after the `min_frequency=0.01` threshold). XGBoost tuning therefore runs ~5–10× longer per trial than on Homesite at the same `N_TRIALS`. GPU acceleration is enabled by default (`XGB_FIXED['device'] = 'cuda'`).
# - **A `gc.collect()` call is added at the end of each side's replica loop** to keep peak RAM bounded between sides; without it, lingering bootstrap arrays from the A-side can occupy memory while the B-side starts allocating its own.
#
# **Input:** `data/processed/`, `data/windows/window_config.json`
# **Output per pair:** `data/models/{model_type}/pair_{pid:02d}/`
# - `replicas_A/encoder.joblib`, `replicas_B/encoder.joblib` — shared per-(window, side) `OrdinalEncoder`s (used by replicas + 03 / 03b)
# - `replicas_A/one_hot.joblib`, `replicas_B/one_hot.joblib` — shared per-(window, side) `OneHotEncoder`s, used by every model
# - `replicas_A/model_r{r}.joblib`, `replicas_B/model_r{r}.joblib` — R fitted models (Pipeline for LR, XGBClassifier for XGB)
# - `replicas_A/seeds_r{r}.json`, `replicas_B/seeds_r{r}.json` — exact bootstrap/model seeds
# - `hparams_A.json`, `hparams_B.json` — tuned hyperparameters
# - `class_weights.json` — realised `{n_pos, n_neg, w_pos, w_neg, data_scope}` for sides A and B (and the full-window LR fits, when applicable)
# - `reference_scaler.joblib` — `StandardScaler` fit on window A's numeric features (used by 04 for covariate drift, and by LR coefficient reprojection)
# - `predictions.npz` — see schema below
# - `coef_A_ref.npy`, `coef_B_ref.npy` *(LR only)* — replica coefficients in the pair-level reference basis with **cat dummies L2-aggregated per cat variable**; shape `(R, n_num + n_bin + n_cat)`
# - `coef_A_full_ref.npy`, `coef_B_full_ref.npy` *(LR only)* — single deterministic full-window LR fit, same reference basis + cat aggregation; shape `(n_num + n_bin + n_cat,)`
# - `full_model_A.joblib`, `full_model_B.joblib` *(LR only)* — fitted full-window LR pipelines (`ColumnTransformer` + `LogisticRegression`)
#
# For XGBoost runs only:
# - `replicas_A/training_log_r{r}.csv`, `replicas_B/training_log_r{r}.csv` — per-replica eval-metric curve
#
# **`predictions.npz` schema (unchanged across model types):**
# | Key | Shape | Meaning |
# |---|---|---|
# | `preds_A` | `(R, n_eval)` | per-replica positive-class probability, window A |
# | `preds_B` | `(R, n_eval)` | per-replica positive-class probability, window B |
# | `p_hat_A` | `(n_eval,)` | replica-averaged probability, window A |
# | `p_hat_B` | `(n_eval,)` | replica-averaged probability, window B |
# | `flagged_idx` | `(n_flagged,)` | local positions within `idx_eval` of the flagged set |
# | `Y_eval` | `(n_eval,)` | true labels |
# | `pr_auc_A` | scalar | average precision of `p_hat_A` (unweighted) |
# | `pr_auc_B` | scalar | average precision of `p_hat_B` (unweighted) |
# | `roc_auc_A` | scalar | ROC-AUC of `p_hat_A` (unweighted) |
# | `roc_auc_B` | scalar | ROC-AUC of `p_hat_B` (unweighted) |
# | `per_replica_pr_auc_A` | `(R,)` | PR-AUC of each individual replica, window A (unweighted) |
# | `per_replica_pr_auc_B` | `(R,)` | PR-AUC of each individual replica, window B (unweighted) |
#
# ---
#
# **Replica design:** Each replica differs by (1) a different random seed and (2) a stratified bootstrap sample drawn from the chronologically-trimmed training window. The shared (window, side) encoder + one-hot, the side-level balanced class-weight mapping, and the deterministic full-window LR fits do **not** vary across replicas — only the bootstrap sample and the model's random initialisation do.

# %%
import gc
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import average_precision_score, roc_auc_score
from xgboost import XGBClassifier
import optuna
from optuna.samplers import TPESampler

optuna.logging.set_verbosity(optuna.logging.WARNING)
import warnings
from scipy.linalg import LinAlgWarning
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings('ignore', category=LinAlgWarning)
warnings.filterwarnings('ignore', category=ConvergenceWarning)

WORKSPACE = Path('/content/drive/MyDrive/Thesis/HomeCredit_workspace')
PROC_DIR  = WORKSPACE / 'data' / 'processed'
WIN_DIR   = WORKSPACE / 'data' / 'windows'

# ── Fixed parameters (not tuned) ──────────────────────────────────────
XGB_FIXED = dict(
    tree_method = 'hist',
    device      = 'cuda',
    eval_metric = 'aucpr',
    verbosity   = 0,
    n_jobs      = -1,
    objective   = 'binary:logistic',
)

import sklearn as _sklearn
_sk_ver = tuple(int(x) for x in _sklearn.__version__.split('.')[:2])
_lr_solver = 'newton-cholesky' if _sk_ver >= (1, 2) else 'lbfgs'

LR_FIXED = dict(
    solver   = _lr_solver,
    max_iter = 300,
)

# ── Tuning configuration ───────────────────────────────────────────────
N_TRIALS       = 25    # Optuna trials per window (XGBoost)
N_TRIALS_LR    = 25    # Optuna trials per window (LogisticRegression)
CV_N_SPLITS    = 3     # TimeSeriesSplit folds inside each window
ES_ROUNDS      = 50    # early-stopping rounds (XGBoost only)
MAX_BOOST_RND  = 2000  # hard cap on n_estimators (XGBoost only)
VAL_TAIL_FRAC  = 0.15  # chronological window tail held out for XGBoost early stopping

# ── Categorical encoding configuration ─────────────────────────────────
# A single OrdinalEncoder is fit per (window, side) on the full window's training
# rows and reused by every bootstrap replica of that side.
# OneHotEncoder is also fit per (window, side) on the OrdinalEncoder's output, so
# nominal categories enter the model as 0/1 dummies rather than monotonic
# integer codes.
CAT_MIN_FREQ  = 0.01
CAT_UNK_VALUE = -1

print('Imports OK')
print(f'LR solver: {_lr_solver}  (sklearn {_sklearn.__version__})')

# %%
# ── Model-type configuration — change this between runs ───────────────
MODEL_TYPE = 'logreg'   # 'xgboost' or 'logreg'

MODEL_DIR = WORKSPACE / 'data' / 'models' / MODEL_TYPE
MODEL_DIR.mkdir(parents=True, exist_ok=True)

print(f'MODEL_TYPE : {MODEL_TYPE}')
print(f'MODEL_DIR  : {MODEL_DIR}')

assert MODEL_TYPE in {'xgboost', 'logreg'}, (
    f"MODEL_TYPE must be either 'xgboost' or 'logreg'. Got: {MODEL_TYPE}"
)

# %%
# ── Load processed data ────────────────────────────────────────────────
X_df = pd.read_parquet(PROC_DIR / 'X.parquet')
X    = X_df.values.astype(np.float32)
Y    = np.load(PROC_DIR / 'Y.npy').astype(np.int8)

# Categoricals are stored as raw strings (object dtype).
X_cat_df = pd.read_parquet(PROC_DIR / 'X_cat.parquet')
X_cat    = np.asarray(X_cat_df, dtype=object)

with open(PROC_DIR / 'feature_names.json') as f:
    feat_names = json.load(f)
num_cols = feat_names['num']                             # numeric feature names
bin_cols = feat_names['bin']                             # binary feature names
cat_cols = feat_names['cat']                             # categorical feature names
num_col_idx = [X_df.columns.get_loc(c) for c in num_cols]  # positions in X (for reference scaler)

with open(WIN_DIR / 'window_config.json') as f:
    config = json.load(f)

R       = config['parameters']['R']
K_FRAC  = config['parameters']['K_FRAC']
pairs   = config['pairs']

n_num_bin = X.shape[1]                       # columns in X.parquet (= num + bin)
n_cat     = X_cat.shape[1]                   # columns in X_cat.parquet
n_total   = n_num_bin + n_cat                # combined feature count fed to models

print(f'X     : {X.shape}     ({len(num_cols)} num + {len(bin_cols)} bin)')
print(f'X_cat : {X_cat.shape}  ({len(cat_cols)} cat features as raw strings)')
print(f'Y     : {Y.shape}')
print(f'R={R}, K_FRAC={K_FRAC}, {len(pairs)} window pairs')
print(f'Combined feature count fed to models: {n_total}')

assert X.shape[0] == Y.shape[0] == X_cat.shape[0], 'X / Y / X_cat row counts inconsistent.'
assert X.shape[1] == len(feat_names['all']),       'X.parquet does not match feature_names["all"].'
assert list(X_df.columns)     == feat_names['all'], 'X.parquet column order mismatch with feature_names["all"].'
assert list(X_cat_df.columns) == cat_cols,          'X_cat.parquet column order mismatch with feature_names["cat"].'
assert len(pairs) > 0, 'No rolling-window pairs found.'

# %% [markdown]
# ## Helper functions

# %%
def stratified_bootstrap(idx: np.ndarray, Y: np.ndarray, seed: int) -> np.ndarray:
    """Stratified bootstrap: sample with replacement, preserving class ratio.

    Returns an array of row indices (into the global X/Y) with length equal to len(idx),
    containing the same number of positives and negatives as the input slice.
    """
    rng = np.random.default_rng(seed)
    pos = idx[Y[idx] == 1]
    neg = idx[Y[idx] == 0]
    boot_pos = rng.choice(pos, size=len(pos), replace=True)
    boot_neg = rng.choice(neg, size=len(neg), replace=True)
    out = np.concatenate([boot_pos, boot_neg])
    rng.shuffle(out)  # mix positives and negatives so any tail split is not all-positive
    return out


def compute_balanced_class_weights(y: np.ndarray) -> tuple[dict, int, int]:
    """Balanced sample-weight scheme equivalent to sklearn's 'balanced':
        w_pos = n / (2 * n_pos),    w_neg = n / (2 * n_neg),    n = n_pos + n_neg.
    Returns ({0: w_neg, 1: w_pos}, n_pos, n_neg). Asserts both classes are present.
    Weights are NOT clipped — extreme ratios surface as large floats by design.
    HomeCredit's ~3% default rate makes w_pos ≈ 16 and w_neg ≈ 0.5 in practice.
    """
    y = np.asarray(y).ravel()
    n_pos = int((y == 1).sum())
    n_neg = int((y == 0).sum())
    n = n_pos + n_neg
    assert n_pos > 0 and n_neg > 0, (
        f"Cannot compute balanced class weights: n_pos={n_pos}, n_neg={n_neg}. "
        "Both classes must be present in the training portion."
    )
    w_pos = n / (2.0 * n_pos)
    w_neg = n / (2.0 * n_neg)
    return {0: float(w_neg), 1: float(w_pos)}, n_pos, n_neg


def sample_weights_from_class_weights(y: np.ndarray, class_weights: dict) -> np.ndarray:
    """Per-row sample weights derived from a {0: w_neg, 1: w_pos} class-weight dict."""
    y = np.asarray(y).ravel()
    return np.where(y == 1, class_weights[1], class_weights[0]).astype(np.float32)


def make_encoder() -> OrdinalEncoder:
    """OrdinalEncoder configured with the TabReD-style frequency threshold.

    Fit per (window, side) on the full window training rows and reused by every
    bootstrap replica of that side. min_frequency=0.01 lumps categories with
    <1% relative frequency into a single bucket; unseen categories at transform
    time get unknown_value (-1).
    """
    return OrdinalEncoder(
        handle_unknown='use_encoded_value',
        unknown_value=CAT_UNK_VALUE,
        min_frequency=CAT_MIN_FREQ,
        encoded_missing_value=CAT_UNK_VALUE,
    )


def make_one_hot() -> OneHotEncoder:
    """OneHotEncoder applied to the OrdinalEncoder's integer output.

    Fit per (window, side) on the same training rows after the OrdinalEncoder,
    shared across XGBoost, LR (this notebook), and MLP-PLR (notebook 02b).
    handle_unknown='ignore' makes any code outside the fitted vocabulary (e.g.
    -1 for unseen categories at transform time) become all-zero across that
    cat's dummies — the safe behaviour for nominal one-hot encoding.
    """
    return OneHotEncoder(
        drop='first' if MODEL_TYPE == 'logreg' else None,
        sparse_output=False,
        handle_unknown='ignore',
        dtype=np.float32,
    )


def get_dummy_groups(one_hot: OneHotEncoder) -> list:
    """Per-cat-variable column index groups in the one-hot output.

    Returns a list of length n_cat, where entry j is the list of one-hot column
    positions belonging to categorical variable j (in the order one_hot was fit).
    Used by `lr_coef_to_reference_basis` to L2-aggregate dummy coefficients into
    one number per cat variable.

    Handles drop=None (K dummies per cat) and drop='first' (K-1 dummies per cat)
    via the encoder's `drop_idx_` attribute.
    """
    drop_idx = getattr(one_hot, 'drop_idx_', None)
    groups, cursor = [], 0
    for j, cats in enumerate(one_hot.categories_):
        n = len(cats)
        if drop_idx is not None and drop_idx[j] is not None:
            n -= 1
        groups.append(list(range(cursor, cursor + n)))
        cursor += n
    return groups


def encode_combined(X_part: np.ndarray,
                    X_cat_str_part: np.ndarray,
                    encoder: OrdinalEncoder,
                    one_hot: OneHotEncoder) -> np.ndarray:
    """Apply pre-fit OrdinalEncoder + OneHotEncoder, hstack with X (numeric+binary).

    Output shape: (n, n_num_bin + n_oh) where n_oh = sum_j K_j (total dummy count).
    Columns: [num | bin | one_hot_dummies] with the first n_num_bin columns
    matching the X.parquet column order. Shared by XGBoost and LR (this
    notebook) and by MLP-PLR (notebook 02b) via the same saved encoder pair.
    """
    ord_codes = encoder.transform(X_cat_str_part)
    oh = one_hot.transform(ord_codes).astype(np.float32)
    return np.hstack([X_part, oh])


def make_lr_pipeline(num_col_idx_list: list,
                      n_total: int,
                      params: dict,
                      model_seed: int) -> Pipeline:
    """Build the LR pipeline: ColumnTransformer + LogisticRegression.

    StandardScaler is applied only to the numeric columns; binary indicators
    and one-hot dummies are passed through on their raw 0/1 scale (already in
    a common reference frame across windows). After ColumnTransformer the
    coefficient layout is [num_coefs (n_num) | bin_coefs (n_bin) | oh_coefs (n_oh)],
    in input-position order within each block.
    """
    num_set  = set(num_col_idx_list)
    rest_idx = [i for i in range(n_total) if i not in num_set]
    ct = ColumnTransformer([
        ('num',  StandardScaler(), list(num_col_idx_list)),
        ('rest', 'passthrough',     rest_idx),
    ])
    return Pipeline([
        ('ct',    ct),
        ('model', LogisticRegression(**{**LR_FIXED, **params, 'random_state': model_seed})),
    ])


def _build_xgb(params: dict, seed: int, early_stopping_rounds: int = None) -> XGBClassifier:
    """Construct an XGBClassifier with fixed settings + tuned params + a given seed."""
    full = {**XGB_FIXED, **params, 'random_state': seed, 'n_estimators': MAX_BOOST_RND}
    if early_stopping_rounds is not None:
        full['early_stopping_rounds'] = early_stopping_rounds
    return XGBClassifier(**full)


def tune_hyperparameters_xgboost(window_idx: np.ndarray,
                                  X_all: np.ndarray,
                                  X_cat_all: np.ndarray,
                                  Y_all: np.ndarray,
                                  encoder: OrdinalEncoder,
                                  one_hot: OneHotEncoder,
                                  study_seed: int,
                                  n_trials: int = N_TRIALS) -> dict:
    """Optuna tuning of XGBoost hyperparameters using TimeSeriesSplit(CV_N_SPLITS).

    The pre-fit shared per-(window, side) OrdinalEncoder + OneHotEncoder are reused
    across folds — the encoder vocabulary is the same as during replica training,
    eliminating any tuning/training preprocessing mismatch. Objective: mean PR-AUC.

    Class weighting: balanced sample weights are computed per fold from the
    fold-training portion only and passed to XGBoost via `sample_weight`. The
    fold-validation portion is used for early-stopping AUCPR and for the returned
    PR-AUC, both unweighted (XGBoost does not apply `sample_weight` to eval_set
    metrics, and `average_precision_score` is called without weights).
    """
    X_win = encode_combined(X_all[window_idx], X_cat_all[window_idx], encoder, one_hot)
    Y_win = Y_all[window_idx]

    tscv = TimeSeriesSplit(n_splits=CV_N_SPLITS)

    def objective(trial: optuna.Trial) -> float:
        params = {
            'max_depth':        trial.suggest_int('max_depth', 4, 10),
            'learning_rate':    trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
            'min_child_weight': trial.suggest_float('min_child_weight', 1.0, 20.0, log=True),
            'subsample':        trial.suggest_float('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            'reg_alpha':        trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
            'reg_lambda':       trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
            'gamma':            trial.suggest_float('gamma', 1e-3, 10.0, log=True),
        }
        pr_aucs = []
        for fold, (tr, va) in enumerate(tscv.split(X_win)):
            cw_fold, _, _ = compute_balanced_class_weights(Y_win[tr])
            sw_tr = sample_weights_from_class_weights(Y_win[tr], cw_fold)
            model = _build_xgb(params, seed=study_seed + fold,
                               early_stopping_rounds=ES_ROUNDS)
            model.fit(X_win[tr], Y_win[tr],
                      sample_weight=sw_tr,
                      eval_set=[(X_win[va], Y_win[va])], verbose=False)
            p = model.predict_proba(X_win[va])[:, 1]
            pr_aucs.append(average_precision_score(Y_win[va], p))
        return float(np.mean(pr_aucs))

    sampler = TPESampler(seed=study_seed)
    study   = optuna.create_study(direction='maximize', sampler=sampler)
    study.optimize(objective, n_trials=n_trials, show_progress_bar=False)
    return dict(study.best_trial.params)


def tune_hyperparameters_logreg(window_idx: np.ndarray,
                                 X_all: np.ndarray,
                                 X_cat_all: np.ndarray,
                                 Y_all: np.ndarray,
                                 encoder: OrdinalEncoder,
                                 one_hot: OneHotEncoder,
                                 num_col_idx_list: list,
                                 study_seed: int,
                                 n_trials: int = N_TRIALS_LR) -> dict:
    """Optuna tuning of LogisticRegression on the given training window.

    Tunes C only; penalty fixed to 'l2'. Pipeline = ColumnTransformer (StandardScaler
    on numerics, passthrough on binary + one-hot dummies) → LogisticRegression. The
    shared per-(window, side) OrdinalEncoder + OneHotEncoder are reused across folds.

    Class weighting: balanced sample weights are computed per fold from the
    fold-training portion only and forwarded into the LR step of the Pipeline via
    `model__sample_weight`. The ColumnTransformer step is unweighted by sklearn
    convention. Fold-validation PR-AUC is computed unweighted.
    """
    X_win = encode_combined(X_all[window_idx], X_cat_all[window_idx], encoder, one_hot)
    Y_win = Y_all[window_idx]
    n_total = X_win.shape[1]

    tscv = TimeSeriesSplit(n_splits=CV_N_SPLITS)

    def objective(trial: optuna.Trial) -> float:
        params = {
            'C':       trial.suggest_float('C', 1e-3, 3, log=True),
            'penalty': 'l2',
        }
        pr_aucs = []
        for fold, (tr, va) in enumerate(tscv.split(X_win)):
            cw_fold, _, _ = compute_balanced_class_weights(Y_win[tr])
            sw_tr = sample_weights_from_class_weights(Y_win[tr], cw_fold)
            pipe = make_lr_pipeline(num_col_idx_list, n_total, params,
                                     model_seed=study_seed + fold)
            pipe.fit(X_win[tr], Y_win[tr], model__sample_weight=sw_tr)
            p = pipe.predict_proba(X_win[va])[:, 1]
            pr_aucs.append(average_precision_score(Y_win[va], p))
        return float(np.mean(pr_aucs))

    sampler = TPESampler(seed=study_seed)
    study   = optuna.create_study(direction='maximize', sampler=sampler)
    study.optimize(objective, n_trials=n_trials, show_progress_bar=False)
    return dict(study.best_trial.params)


def train_replica_with_es(X_train_combined: np.ndarray,
                           Y_train: np.ndarray,
                           X_val_combined: np.ndarray,
                           Y_val: np.ndarray,
                           params: dict,
                           model_seed: int,
                           sample_weight: np.ndarray):
    """Train one XGBoost replica on a bootstrap sample with early stopping.

    Inputs are already-combined (numeric + binary + one-hot dummies) matrices.
    `sample_weight` is the per-row weight vector built from the side/window-level
    class-weight mapping (see compute_balanced_class_weights). It is applied to the
    training objective only; validation AUCPR (early stopping) and predictions
    remain unweighted.

    Returns (model, training_log_df).
    """
    model = _build_xgb(params, seed=model_seed, early_stopping_rounds=ES_ROUNDS)
    model.fit(X_train_combined, Y_train,
              sample_weight=sample_weight,
              eval_set=[(X_val_combined, Y_val)], verbose=False)
    evals_result = model.evals_result()
    val_curve = evals_result.get('validation_0', {}).get('aucpr', [])
    training_log = pd.DataFrame({
        'iteration': np.arange(1, len(val_curve) + 1),
        'val_aucpr': val_curve,
    })
    return model, training_log


def train_replica_logreg(X_train_combined: np.ndarray,
                          Y_train: np.ndarray,
                          num_col_idx_list: list,
                          params: dict,
                          model_seed: int,
                          sample_weight: np.ndarray) -> Pipeline:
    """Train one LR replica via the ColumnTransformer pipeline with balanced sample
    weights forwarded into the LR step."""
    pipe = make_lr_pipeline(num_col_idx_list, X_train_combined.shape[1], params, model_seed)
    pipe.fit(X_train_combined, Y_train, model__sample_weight=sample_weight)
    return pipe


def lr_coef_to_reference_basis(pipe: Pipeline,
                                reference_scaler: StandardScaler,
                                num_col_idx_list: list,
                                n_num_bin: int,
                                dummy_groups: list) -> np.ndarray:
    """Project an LR replica's coefficients to a common pair-level reference basis.

    The pipeline is `ColumnTransformer({num: StandardScaler, rest: passthrough})
    → LogisticRegression`. After ColumnTransformer the coefficient block is laid
    out as [num_coefs (n_num) | bin_coefs (n_bin) | oh_coefs (n_oh)].

    Numeric coefs are reprojected by training σ → reference σ. Binary coefs stay
    on the raw 0/1 scale (already a common reference frame across windows).
    One-hot dummy coefs are L2-aggregated per cat variable to recover one number
    per categorical feature.

    Output shape: (n_num_bin + n_cat,) — order matches
    `feature_names['all'] + feature_names['cat']` from notebook 00.
    """
    ct    = pipe.named_steps['ct']
    model = pipe.named_steps['model']

    n_num = len(num_col_idx_list)
    n_bin = n_num_bin - n_num
    n_cat = len(dummy_groups)
    n_oh  = sum(len(g) for g in dummy_groups)

    beta_full = model.coef_.ravel().astype(np.float64)
    assert beta_full.shape[0] == n_num + n_bin + n_oh, (
        f'LR coef vector length {beta_full.shape[0]} does not match expected '
        f'n_num + n_bin + n_oh = {n_num + n_bin + n_oh}'
    )

    beta_num_std = beta_full[:n_num]
    beta_rest    = beta_full[n_num:]
    beta_bin     = beta_rest[:n_bin]
    beta_oh      = beta_rest[n_bin:]

    train_sigma = ct.named_transformers_['num'].scale_.astype(np.float64)
    train_sigma_safe = np.where(train_sigma == 0.0, 1.0, train_sigma)
    ref_sigma   = reference_scaler.scale_.astype(np.float64)
    beta_num_ref = beta_num_std / train_sigma_safe * ref_sigma

    beta_cat_ref = np.array(
        [np.linalg.norm(beta_oh[group]) for group in dummy_groups],
        dtype=np.float64,
    )

    # Reassemble in [num | bin | cat] order. Numeric and binary positions follow
    # X.parquet column order; cat aggregates are appended in X_cat column order.
    num_set = set(num_col_idx_list)
    bin_positions_ordered = [j for j in range(n_num_bin) if j not in num_set]
    out = np.zeros(n_num_bin + n_cat, dtype=np.float64)
    for pos_in_num, j in enumerate(num_col_idx_list):
        out[j] = beta_num_ref[pos_in_num]
    for pos_in_bin, j in enumerate(bin_positions_ordered):
        out[j] = beta_bin[pos_in_bin]
    out[n_num_bin:] = beta_cat_ref
    return out.astype(np.float32)


def train_full_window_logreg(X_train_combined: np.ndarray,
                              Y_train: np.ndarray,
                              num_col_idx_list: list,
                              params: dict,
                              model_seed: int,
                              sample_weight: np.ndarray) -> Pipeline:
    """Deterministic full-window LR fit (no bootstrap). Sample weights are computed
    from the full training window (no early-stopping tail for LR) using the
    balanced scheme — same principle as the replica fits, applied to the full window.
    """
    return train_replica_logreg(
        X_train_combined, Y_train, num_col_idx_list, params, model_seed,
        sample_weight=sample_weight,
    )


def predict_proba_pos(model, X_in: np.ndarray) -> np.ndarray:
    """Return probability of positive class."""
    return model.predict_proba(X_in)[:, 1]


def compute_flagged_topk(p_hat_A: np.ndarray,
                          p_hat_B: np.ndarray,
                          k_frac: float) -> np.ndarray:
    """Top-K% flagged set: the top k_frac fraction ranked by max(p_hat_A, p_hat_B)."""
    assert p_hat_A.shape == p_hat_B.shape
    n = len(p_hat_A)
    k = max(int(np.ceil(k_frac * n)), 1)
    score = np.maximum(p_hat_A, p_hat_B)
    topk_unsorted = np.argpartition(-score, k - 1)[:k]
    return np.sort(topk_unsorted)


def assert_binary_slice(y, name):
    assert len(np.unique(y)) == 2, f'{name} contains only one class.'


print('Helpers defined.')

# %% [markdown]
# ## Main training loop — one iteration per window pair

# %%
SEED_BASE = 42

# ── Class-weighting policy (operational retraining pipeline) ──────────────
# Balanced sample weights (sklearn-equivalent: w_c = n / (2 * n_c)) are applied
# to every training fit — Optuna folds, replica fits, and the deterministic
# full-window LR fit. Weights are computed from the actual optimization-training
# portion only (training core before any early-stopping tail; the full window
# for LR which has no ES tail). All replicas within the same side/window share
# one class-weight mapping. Validation/evaluation PR-AUC remains unweighted.
# HomeCredit's ~3% default rate makes w_pos ≈ 16 and w_neg ≈ 0.5 — the asymmetry
# is by design and is NOT clipped.
CLASS_WEIGHTING = {
    'enabled':                    True,
    'scheme':                     'balanced_sample_weights',
    'formula':                    'w_pos = n / (2 * n_pos); w_neg = n / (2 * n_neg)',
    'clipped':                    False,
    'evaluation_pr_auc_weighted': False,
    'replica_data_scope':         (
        'training_core_before_early_stopping_tail'
        if MODEL_TYPE == 'xgboost'
        else 'full_window_no_es'
    ),
    'tuning_data_scope':          'fold_training_only',
    'lr_full_window_data_scope':  'full_window_no_es' if MODEL_TYPE == 'logreg' else None,
}

# Full run-configuration fingerprint used for staleness detection.
# If any of these settings change, existing predictions are treated as stale and the pair is re-run.
CURRENT_RUN_PARAMS = {
    'model_type':  MODEL_TYPE,
    'seed_base':   SEED_BASE,

    'window_parameters': {
        'L':           int(config['parameters']['L']),
        'S':           int(config['parameters']['S']),
        'H':           int(config['parameters']['H']),
        'R':           int(R),
        'K_FRAC':      float(K_FRAC),
        'PAIR_STRIDE': int(config['parameters'].get('PAIR_STRIDE', 1)),
    },

    'cv_n_splits':   int(CV_N_SPLITS),
    'cat_min_freq':  float(CAT_MIN_FREQ),
    'cat_unk_value': int(CAT_UNK_VALUE),
    'encoder_scope': 'per_window_side_shared',

    # Class weighting (scheme metadata; per-pair n_pos/n_neg/w_pos/w_neg are
    # written to class_weights.json inside each pair directory).
    'class_weighting': CLASS_WEIGHTING,
}

if MODEL_TYPE == 'logreg':
    CURRENT_RUN_PARAMS['lr_reference_basis_schema']    = 'coef_ref_basis_v2_homecredit_oh_l2'
    CURRENT_RUN_PARAMS['lr_full_window_reference_fit'] = True
    CURRENT_RUN_PARAMS['lr_cat_aggregation']           = 'l2_norm_per_cat_var'
    CURRENT_RUN_PARAMS['n_trials_logreg']              = int(N_TRIALS_LR)
    CURRENT_RUN_PARAMS['lr_fixed']                     = LR_FIXED
else:  # xgboost
    CURRENT_RUN_PARAMS.update({
        'n_trials_xgboost':  int(N_TRIALS),
        'es_rounds':         int(ES_ROUNDS),
        'max_boost_round':   int(MAX_BOOST_RND),
        'val_tail_frac':     float(VAL_TAIL_FRAC),
        'xgb_fixed':         XGB_FIXED,
        'xgb_cat_encoding':  'one_hot_per_window_l2_threshold',
    })

performance_log = []

for p in pairs:
    pid                = p['pair_id']
    pair_dir           = MODEL_DIR / f'pair_{pid:02d}'
    pred_file          = pair_dir / 'predictions.npz'
    run_params_file    = pair_dir / 'run_params.json'
    class_weights_file = pair_dir / 'class_weights.json'

    # ── Skip-if-done: validate full run configuration against saved run_params ──
    # Checking only for predictions.npz existence is insufficient: if tuning,
    # model, window, selection, or class-weighting settings change, existing
    # predictions are stale.
    if pred_file.exists() and run_params_file.exists():
        with open(run_params_file) as f:
            saved = json.load(f)
        params_match = (saved == CURRENT_RUN_PARAMS)

        required_lr_files = [
            pair_dir / 'coef_A_ref.npy',
            pair_dir / 'coef_B_ref.npy',
            pair_dir / 'coef_A_full_ref.npy',
            pair_dir / 'coef_B_full_ref.npy',
            pair_dir / 'full_model_A.joblib',
            pair_dir / 'full_model_B.joblib',
        ]
        if MODEL_TYPE == 'logreg' and not all(pp.exists() for pp in required_lr_files):
            print(f'Pair {pid:02d}: LR coefficient artefacts missing — re-running.')
        elif not class_weights_file.exists():
            print(f'Pair {pid:02d}: class_weights.json missing — re-running.')
        else:
            if params_match:
                data = np.load(pred_file)
                if all(k in data.files for k in ('roc_auc_A', 'roc_auc_B')):
                    print(f'Pair {pid:02d}: already done, skipping.')
                    performance_log.append({
                        'pair_id':   pid,
                        'pr_auc_A':  float(data['pr_auc_A']),
                        'pr_auc_B':  float(data['pr_auc_B']),
                        'roc_auc_A': float(data['roc_auc_A']),
                        'roc_auc_B': float(data['roc_auc_B']),
                        'n_flagged': int(data['flagged_idx'].shape[0]),
                    })
                    continue
                else:
                    print(f'Pair {pid:02d}: stale predictions.npz (missing roc_auc keys) — re-running.')
            else:
                changed_keys = [k for k in CURRENT_RUN_PARAMS if saved.get(k) != CURRENT_RUN_PARAMS[k]]
                print(f'Pair {pid:02d}: run_params changed in {changed_keys} — re-running.')
    elif pred_file.exists():
        print(f'Pair {pid:02d}: run_params.json missing — re-running.')

    print(f'\n── [{MODEL_TYPE}] Pair {pid:02d}: A_end={p["step_label_A"]}  B_end={p["step_label_B"]}  '
          f'eval={p["eval_start_label"]}→{p["eval_end_label"]}  '
          f'|A|={p["n_train_A"]:,} |B|={p["n_train_B"]:,} |eval|={p["n_eval"]:,} ──')

    idx_A    = np.array(p['idx_A'],    dtype=np.int64)
    idx_B    = np.array(p['idx_B'],    dtype=np.int64)
    idx_eval = np.array(p['idx_eval'], dtype=np.int64)

    assert len(set(idx_A.tolist()) & set(idx_eval.tolist())) == 0, 'idx_A and idx_eval overlap!'
    assert len(set(idx_B.tolist()) & set(idx_eval.tolist())) == 0, 'idx_B and idx_eval overlap!'

    X_eval     = X[idx_eval]
    X_cat_eval = X_cat[idx_eval]
    Y_eval     = Y[idx_eval]

    assert_binary_slice(Y[idx_A], f'pair {pid:02d} window A')
    assert_binary_slice(Y[idx_B], f'pair {pid:02d} window B')
    assert_binary_slice(Y_eval,   f'pair {pid:02d} eval slice')

    pair_dir.mkdir(parents=True, exist_ok=True)
    dir_A = pair_dir / 'replicas_A'
    dir_B = pair_dir / 'replicas_B'
    dir_A.mkdir(exist_ok=True)
    dir_B.mkdir(exist_ok=True)

    # ── Reference scaler: window-A numeric features (used by nb 04 + LR coefficient reprojection) ──
    ref_scaler = StandardScaler()
    ref_scaler.fit(X[idx_A][:, num_col_idx])
    joblib.dump(ref_scaler, pair_dir / 'reference_scaler.joblib')

    # ── Shared per-(window, side) OrdinalEncoders (used by replicas, tuning, and 03 / 03b) ──
    encoder_A = make_encoder()
    encoder_A.fit(X_cat[idx_A])
    joblib.dump(encoder_A, dir_A / 'encoder.joblib')
    encoder_B = make_encoder()
    encoder_B.fit(X_cat[idx_B])
    joblib.dump(encoder_B, dir_B / 'encoder.joblib')

    # ── Shared per-(window, side) OneHotEncoders (used by every model) ──
    one_hot_A = make_one_hot()
    one_hot_A.fit(encoder_A.transform(X_cat[idx_A]))
    joblib.dump(one_hot_A, dir_A / 'one_hot.joblib')

    one_hot_B = make_one_hot()
    one_hot_B.fit(encoder_B.transform(X_cat[idx_B]))
    joblib.dump(one_hot_B, dir_B / 'one_hot.joblib')

    dummy_groups_A = get_dummy_groups(one_hot_A)
    dummy_groups_B = get_dummy_groups(one_hot_B)
    n_oh_A = sum(len(g) for g in dummy_groups_A)
    n_oh_B = sum(len(g) for g in dummy_groups_B)
    print(f'  one-hot dummies: A={n_oh_A}, B={n_oh_B}  (n_cat={n_cat} cat variables)')

    # ── Tune hyperparameters per window ──
    print('  Tuning window A ...')
    if MODEL_TYPE == 'xgboost':
        hparams_A = tune_hyperparameters_xgboost(
            idx_A, X, X_cat, Y, encoder_A, one_hot_A,
            study_seed=SEED_BASE + pid * 10 + 1,
        )
    else:
        hparams_A = tune_hyperparameters_logreg(
            idx_A, X, X_cat, Y, encoder_A, one_hot_A, num_col_idx,
            study_seed=SEED_BASE + pid * 10 + 1,
        )
    with open(pair_dir / 'hparams_A.json', 'w') as f:
        json.dump(hparams_A, f, indent=2)
    print(f'    best A params: {hparams_A}')

    print('  Tuning window B ...')
    if MODEL_TYPE == 'xgboost':
        hparams_B = tune_hyperparameters_xgboost(
            idx_B, X, X_cat, Y, encoder_B, one_hot_B,
            study_seed=SEED_BASE + pid * 10 + 2,
        )
    else:
        hparams_B = tune_hyperparameters_logreg(
            idx_B, X, X_cat, Y, encoder_B, one_hot_B, num_col_idx,
            study_seed=SEED_BASE + pid * 10 + 2,
        )
    with open(pair_dir / 'hparams_B.json', 'w') as f:
        json.dump(hparams_B, f, indent=2)
    print(f'    best B params: {hparams_B}')

    # ── Chronological ES validation split (XGBoost only; done before bootstrapping) ──
    if MODEL_TYPE == 'xgboost':
        n_es_A     = max(int(np.ceil(len(idx_A) * VAL_TAIL_FRAC)), 1)
        idx_A_boot = idx_A[:-n_es_A]
        idx_A_es   = idx_A[-n_es_A:]
        n_es_B     = max(int(np.ceil(len(idx_B) * VAL_TAIL_FRAC)), 1)
        idx_B_boot = idx_B[:-n_es_B]
        idx_B_es   = idx_B[-n_es_B:]

        assert_binary_slice(Y[idx_A_es],   f'pair {pid:02d} A ES tail')
        assert_binary_slice(Y[idx_B_es],   f'pair {pid:02d} B ES tail')
        assert_binary_slice(Y[idx_A_boot], f'pair {pid:02d} A bootstrap source')
        assert_binary_slice(Y[idx_B_boot], f'pair {pid:02d} B bootstrap source')
        weighting_scope = 'training_core_before_early_stopping_tail'
    else:
        idx_A_boot = idx_A   # logreg has no early stopping
        idx_B_boot = idx_B
        weighting_scope = 'full_window_no_es'

    # ── Side/window-level balanced class weights (computed once per side) ──
    # All replicas within a side share this mapping. The bootstrap is class-
    # stratified, so the per-class counts in each bootstrap sample equal those
    # of the bootstrap source — but we still apply the side-level dict directly
    # (rather than recomputing) so the policy is enforced explicitly. A and B
    # may end up with different weights because their class balance can differ.
    cw_A, n_pos_A, n_neg_A = compute_balanced_class_weights(Y[idx_A_boot])
    cw_B, n_pos_B, n_neg_B = compute_balanced_class_weights(Y[idx_B_boot])
    print(f'  Class weights A (scope={weighting_scope}): '
          f'n_pos={n_pos_A:,}  n_neg={n_neg_A:,}  '
          f'w_pos={cw_A[1]:.4f}  w_neg={cw_A[0]:.4f}')
    print(f'  Class weights B (scope={weighting_scope}): '
          f'n_pos={n_pos_B:,}  n_neg={n_neg_B:,}  '
          f'w_pos={cw_B[1]:.4f}  w_neg={cw_B[0]:.4f}')

    pair_class_weights_meta = {
        'scheme':                     'balanced_sample_weights',
        'formula':                    'w_pos = n / (2 * n_pos); w_neg = n / (2 * n_neg)',
        'clipped':                    False,
        'evaluation_pr_auc_weighted': False,
        'replica_data_scope':         weighting_scope,
        'A': {
            'n_pos': int(n_pos_A), 'n_neg': int(n_neg_A),
            'w_pos': float(cw_A[1]), 'w_neg': float(cw_A[0]),
            'data_scope': weighting_scope,
        },
        'B': {
            'n_pos': int(n_pos_B), 'n_neg': int(n_neg_B),
            'w_pos': float(cw_B[1]), 'w_neg': float(cw_B[0]),
            'data_scope': weighting_scope,
        },
    }

    # ── Train R replicas for window A ──
    preds_A          = np.zeros((R, len(idx_eval)), dtype=np.float32)
    per_rep_pr_auc_A = np.zeros(R, dtype=np.float32)
    if MODEL_TYPE == 'logreg':
        coef_A_ref = np.zeros((R, n_num_bin + n_cat), dtype=np.float32)

    for r in range(R):
        boot_seed  = SEED_BASE + pid * 10_000 + r * 2          # A-bootstrap seeds are even
        model_seed = SEED_BASE + pid * 10_000 + r * 2 + 1      # A-model seeds are odd
        boot_idx   = stratified_bootstrap(idx_A_boot, Y, seed=boot_seed)
        Y_tr       = Y[boot_idx]
        sw_tr      = sample_weights_from_class_weights(Y_tr, cw_A)
        # Verify all replicas in this side use the same {w_neg, w_pos} pair
        # (float32 tolerance, since sample_weights_from_class_weights casts to float32).
        _uniq = np.unique(sw_tr)
        assert len(_uniq) <= 2 and all(
            min(abs(float(u) - cw_A[0]), abs(float(u) - cw_A[1])) < 1e-5 for u in _uniq
        ), (
            f'pair {pid:02d} A r{r}: replica sample weights deviate from the '
            f'side-level class-weight mapping.'
        )

        if MODEL_TYPE == 'xgboost':
            X_tr_combined   = encode_combined(X[boot_idx], X_cat[boot_idx], encoder_A, one_hot_A)
            X_va_combined   = encode_combined(X[idx_A_es], X_cat[idx_A_es], encoder_A, one_hot_A)
            X_eval_combined = encode_combined(X_eval,      X_cat_eval,      encoder_A, one_hot_A)
            model, training_log = train_replica_with_es(
                X_tr_combined, Y_tr, X_va_combined, Y[idx_A_es], hparams_A, model_seed,
                sample_weight=sw_tr,
            )
            preds_A[r] = predict_proba_pos(model, X_eval_combined)
            joblib.dump(model, dir_A / f'model_r{r}.joblib', compress=3)
            training_log.to_csv(dir_A / f'training_log_r{r}.csv', index=False)
        else:  # logreg
            X_tr_combined   = encode_combined(X[boot_idx], X_cat[boot_idx], encoder_A, one_hot_A)
            X_eval_combined = encode_combined(X_eval,      X_cat_eval,      encoder_A, one_hot_A)
            pipeline = train_replica_logreg(
                X_tr_combined, Y_tr, num_col_idx, hparams_A, model_seed,
                sample_weight=sw_tr,
            )
            preds_A[r] = pipeline.predict_proba(X_eval_combined)[:, 1]
            coef_A_ref[r] = lr_coef_to_reference_basis(
                pipe=pipeline, reference_scaler=ref_scaler,
                num_col_idx_list=num_col_idx, n_num_bin=n_num_bin,
                dummy_groups=dummy_groups_A,
            )
            joblib.dump(pipeline, dir_A / f'model_r{r}.joblib', compress=3)

        per_rep_pr_auc_A[r] = average_precision_score(Y_eval, preds_A[r])
        with open(dir_A / f'seeds_r{r}.json', 'w') as f:
            json.dump({'bootstrap_seed': int(boot_seed),
                       'model_seed':     int(model_seed)}, f, indent=2)
        print(f'  A replica {r}: PR-AUC = {per_rep_pr_auc_A[r]:.4f}')

    # Free A-side bootstrap arrays before B-side starts allocating its own.
    gc.collect()

    # ── Train R replicas for window B ──
    preds_B          = np.zeros((R, len(idx_eval)), dtype=np.float32)
    per_rep_pr_auc_B = np.zeros(R, dtype=np.float32)
    if MODEL_TYPE == 'logreg':
        coef_B_ref = np.zeros((R, n_num_bin + n_cat), dtype=np.float32)

    for r in range(R):
        boot_seed  = SEED_BASE + pid * 10_000 + 5_000 + r * 2
        model_seed = SEED_BASE + pid * 10_000 + 5_000 + r * 2 + 1
        boot_idx   = stratified_bootstrap(idx_B_boot, Y, seed=boot_seed)
        Y_tr       = Y[boot_idx]
        sw_tr      = sample_weights_from_class_weights(Y_tr, cw_B)
        # Same float32-tolerant check as side A above.
        _uniq = np.unique(sw_tr)
        assert len(_uniq) <= 2 and all(
            min(abs(float(u) - cw_B[0]), abs(float(u) - cw_B[1])) < 1e-5 for u in _uniq
        ), (
            f'pair {pid:02d} B r{r}: replica sample weights deviate from the '
            f'side-level class-weight mapping.'
        )

        if MODEL_TYPE == 'xgboost':
            X_tr_combined   = encode_combined(X[boot_idx], X_cat[boot_idx], encoder_B, one_hot_B)
            X_va_combined   = encode_combined(X[idx_B_es], X_cat[idx_B_es], encoder_B, one_hot_B)
            X_eval_combined = encode_combined(X_eval,      X_cat_eval,      encoder_B, one_hot_B)
            model, training_log = train_replica_with_es(
                X_tr_combined, Y_tr, X_va_combined, Y[idx_B_es], hparams_B, model_seed,
                sample_weight=sw_tr,
            )
            preds_B[r] = predict_proba_pos(model, X_eval_combined)
            joblib.dump(model, dir_B / f'model_r{r}.joblib', compress=3)
            training_log.to_csv(dir_B / f'training_log_r{r}.csv', index=False)
        else:
            X_tr_combined   = encode_combined(X[boot_idx], X_cat[boot_idx], encoder_B, one_hot_B)
            X_eval_combined = encode_combined(X_eval,      X_cat_eval,      encoder_B, one_hot_B)
            pipeline = train_replica_logreg(
                X_tr_combined, Y_tr, num_col_idx, hparams_B, model_seed,
                sample_weight=sw_tr,
            )
            preds_B[r] = pipeline.predict_proba(X_eval_combined)[:, 1]
            coef_B_ref[r] = lr_coef_to_reference_basis(
                pipe=pipeline, reference_scaler=ref_scaler,
                num_col_idx_list=num_col_idx, n_num_bin=n_num_bin,
                dummy_groups=dummy_groups_B,
            )
            joblib.dump(pipeline, dir_B / f'model_r{r}.joblib', compress=3)

        per_rep_pr_auc_B[r] = average_precision_score(Y_eval, preds_B[r])
        with open(dir_B / f'seeds_r{r}.json', 'w') as f:
            json.dump({'bootstrap_seed': int(boot_seed),
                       'model_seed':     int(model_seed)}, f, indent=2)
        print(f'  B replica {r}: PR-AUC = {per_rep_pr_auc_B[r]:.4f}')

    # Free B-side bootstrap arrays before the next pair starts.
    gc.collect()

    # ── LR coefficient saving + full-window reference fits ──
    if MODEL_TYPE == 'logreg':
        np.save(pair_dir / 'coef_A_ref.npy', coef_A_ref)
        np.save(pair_dir / 'coef_B_ref.npy', coef_B_ref)
        print(f'  Saved coef_A_ref.npy   shape={coef_A_ref.shape}  (n_num_bin + n_cat = {n_num_bin}+{n_cat})')
        print(f'  Saved coef_B_ref.npy   shape={coef_B_ref.shape}')

        print('  Training full-window LR reference models ...')
        full_seed_A = SEED_BASE + pid * 10_000 + 999
        full_seed_B = SEED_BASE + pid * 10_000 + 5_999

        # Class weights for the full-window fits are computed from the full window
        # itself (no early-stopping tail for LR), following the same balanced scheme.
        cw_A_full, n_pos_A_full, n_neg_A_full = compute_balanced_class_weights(Y[idx_A])
        cw_B_full, n_pos_B_full, n_neg_B_full = compute_balanced_class_weights(Y[idx_B])
        sw_A_full = sample_weights_from_class_weights(Y[idx_A], cw_A_full)
        sw_B_full = sample_weights_from_class_weights(Y[idx_B], cw_B_full)
        print(f'    full-window A: n_pos={n_pos_A_full:,}  n_neg={n_neg_A_full:,}  '
              f'w_pos={cw_A_full[1]:.4f}  w_neg={cw_A_full[0]:.4f}')
        print(f'    full-window B: n_pos={n_pos_B_full:,}  n_neg={n_neg_B_full:,}  '
              f'w_pos={cw_B_full[1]:.4f}  w_neg={cw_B_full[0]:.4f}')

        pair_class_weights_meta['A_full_window'] = {
            'n_pos': int(n_pos_A_full), 'n_neg': int(n_neg_A_full),
            'w_pos': float(cw_A_full[1]), 'w_neg': float(cw_A_full[0]),
            'data_scope': 'full_window_no_es',
        }
        pair_class_weights_meta['B_full_window'] = {
            'n_pos': int(n_pos_B_full), 'n_neg': int(n_neg_B_full),
            'w_pos': float(cw_B_full[1]), 'w_neg': float(cw_B_full[0]),
            'data_scope': 'full_window_no_es',
        }

        X_full_A    = encode_combined(X[idx_A], X_cat[idx_A], encoder_A, one_hot_A)
        full_pipe_A = train_full_window_logreg(
            X_full_A, Y[idx_A], num_col_idx, hparams_A, full_seed_A,
            sample_weight=sw_A_full,
        )

        X_full_B    = encode_combined(X[idx_B], X_cat[idx_B], encoder_B, one_hot_B)
        full_pipe_B = train_full_window_logreg(
            X_full_B, Y[idx_B], num_col_idx, hparams_B, full_seed_B,
            sample_weight=sw_B_full,
        )

        coef_A_full_ref = lr_coef_to_reference_basis(
            pipe=full_pipe_A, reference_scaler=ref_scaler,
            num_col_idx_list=num_col_idx, n_num_bin=n_num_bin,
            dummy_groups=dummy_groups_A,
        )
        coef_B_full_ref = lr_coef_to_reference_basis(
            pipe=full_pipe_B, reference_scaler=ref_scaler,
            num_col_idx_list=num_col_idx, n_num_bin=n_num_bin,
            dummy_groups=dummy_groups_B,
        )

        joblib.dump(full_pipe_A, pair_dir / 'full_model_A.joblib', compress=3)
        joblib.dump(full_pipe_B, pair_dir / 'full_model_B.joblib', compress=3)
        np.save(pair_dir / 'coef_A_full_ref.npy', coef_A_full_ref)
        np.save(pair_dir / 'coef_B_full_ref.npy', coef_B_full_ref)

        print(f'  Saved full_model_A/B.joblib (encoders + one-hot live in replicas_A/B/)')
        print(f'  Saved coef_A_full_ref.npy shape={coef_A_full_ref.shape}')
        print(f'  Saved coef_B_full_ref.npy shape={coef_B_full_ref.shape}')

        del X_full_A, X_full_B, full_pipe_A, full_pipe_B
        gc.collect()

    # ── Replica-averaged predictions and flagged set ──
    # Predictions are ordinary positive-class probabilities — sample weights affect
    # the training objective only, not the model's output transformation.
    p_hat_A = preds_A.mean(axis=0)
    p_hat_B = preds_B.mean(axis=0)
    flagged_local_idx = compute_flagged_topk(p_hat_A, p_hat_B, K_FRAC)

    # Validation/evaluation PR-AUC and ROC-AUC are unweighted by construction.
    pr_auc_A  = average_precision_score(Y_eval, p_hat_A)
    pr_auc_B  = average_precision_score(Y_eval, p_hat_B)
    roc_auc_A = roc_auc_score(Y_eval, p_hat_A)
    roc_auc_B = roc_auc_score(Y_eval, p_hat_B)

    print(f'  Averaged: PR-AUC A = {pr_auc_A:.4f}, PR-AUC B = {pr_auc_B:.4f}')
    print(f'            ROC-AUC A = {roc_auc_A:.4f}, ROC-AUC B = {roc_auc_B:.4f}')
    print(f'  Flagged (top {K_FRAC:.0%}): {flagged_local_idx.shape[0]:,} / {len(idx_eval):,}')

    np.savez_compressed(
        pred_file,
        preds_A              = preds_A,
        preds_B              = preds_B,
        p_hat_A              = p_hat_A,
        p_hat_B              = p_hat_B,
        flagged_idx          = flagged_local_idx,
        Y_eval               = Y_eval,
        pr_auc_A             = np.float32(pr_auc_A),
        pr_auc_B             = np.float32(pr_auc_B),
        roc_auc_A            = np.float32(roc_auc_A),
        roc_auc_B            = np.float32(roc_auc_B),
        per_replica_pr_auc_A = per_rep_pr_auc_A,
        per_replica_pr_auc_B = per_rep_pr_auc_B,
    )

    with open(run_params_file, 'w') as f:
        json.dump(CURRENT_RUN_PARAMS, f, indent=2)

    # ── Save per-pair class-weighting metadata for transparency ──
    # The scheme itself is part of the staleness fingerprint via CURRENT_RUN_PARAMS;
    # this file records the realised n_pos / n_neg / w_pos / w_neg per side.
    with open(class_weights_file, 'w') as f:
        json.dump(pair_class_weights_meta, f, indent=2)

    performance_log.append({
        'pair_id':   pid,
        'pr_auc_A':  pr_auc_A,
        'pr_auc_B':  pr_auc_B,
        'roc_auc_A': roc_auc_A,
        'roc_auc_B': roc_auc_B,
        'n_flagged': flagged_local_idx.shape[0],
    })

    # Tidy up between pairs to keep peak RAM bounded across the loop.
    del preds_A, preds_B, p_hat_A, p_hat_B, X_eval, X_cat_eval, Y_eval
    if MODEL_TYPE == 'logreg':
        del coef_A_ref, coef_B_ref
    gc.collect()

print('\n✓ All window pairs processed.')

# %%
perf_df = pd.DataFrame(performance_log)
print(perf_df.to_string(index=False))
print(f'\nMean PR-AUC  A: {perf_df["pr_auc_A"].mean():.4f}   B: {perf_df["pr_auc_B"].mean():.4f}')
print(f'Mean ROC-AUC A: {perf_df["roc_auc_A"].mean():.4f}   B: {perf_df["roc_auc_B"].mean():.4f}')

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].plot(perf_df['pair_id'], perf_df['pr_auc_A'], 'o-',  label='Model A')
axes[0].plot(perf_df['pair_id'], perf_df['pr_auc_B'], 's--', label='Model B')
axes[0].set_title('PR-AUC over window pairs')
axes[0].set_xlabel('Window pair')
axes[0].set_ylabel('PR-AUC')
axes[0].set_xticks(perf_df['pair_id'])
axes[0].legend()
axes[0].set_ylim(0, 1)

axes[1].plot(perf_df['pair_id'], perf_df['roc_auc_A'], 'o-',  label='Model A')
axes[1].plot(perf_df['pair_id'], perf_df['roc_auc_B'], 's--', label='Model B')
axes[1].set_title('ROC-AUC over window pairs')
axes[1].set_xlabel('Window pair')
axes[1].set_ylabel('ROC-AUC')
axes[1].set_xticks(perf_df['pair_id'])
axes[1].legend()
axes[1].set_ylim(0.5, 1)

axes[2].bar(perf_df['pair_id'], perf_df['n_flagged'], color='tomato')
axes[2].set_title(f'Flagged instances per pair (top {int(K_FRAC*100)}%)')
axes[2].set_xlabel('Window pair')
axes[2].set_ylabel('|F_{A,B}|')
axes[2].set_xticks(perf_df['pair_id'])

plt.tight_layout()
plt.savefig(MODEL_DIR / 'performance_summary.png', dpi=120)
plt.show()

# %%
perf_df.to_csv(MODEL_DIR / 'performance_log.csv', index=False)
print('Performance log saved.')
